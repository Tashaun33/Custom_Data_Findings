# %% [markdown]
# My Data project findings. new 2025

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Set the random seed for reproducibility
np.random.seed(101) 
# Load the dataset
df = pd.read_csv('carprices.csv')
# Display the first few rows of the dataframe
print(df.head())
# Plotting the data
plt.figure(figsize=(8, 4))
#plt.title('Scatter Plot of Col3 vs Col6')
plt.xlabel('Col3')
plt.ylabel('Col6')
plt.show()  
# Display the data types of the columns
# Display the shape of the dataframe
print("Shape of the dataframe:", df.shape)
# Display the summary statistics of the dataframe
print(df.describe())
# Display the first few rows of the dataframe
print(df.head())
# Display the last few rows of the dataframe
print(df.tail())
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
this looks better the type i might need to work on.

# %%
df = pd.read_csv('carprices.csv' )
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
plt.title('Car Prices vs Models')

plt.plot([' 11000',' 12000','13000','14000',' 15000'])  # Example data for car prices

plt.xlabel('Car Models')  

plt.plot(['Honda', 'Toyota', 'Audi', 'Bmw', 'Mercedes'])   
plt.ylabel('Prices in $')

plt.show()

# %% [markdown]
# Yes, this is a chart to show the cost of a 4 wheel car and quality, r u listening..??? please pay attention...

# %% [markdown]
# from my chart i can tell you  that in the 4 wheel industry you will get what you pay for if you ask for it by name. the motto is 'Reasurringly expensive' as my chart will verify this anomoly...
